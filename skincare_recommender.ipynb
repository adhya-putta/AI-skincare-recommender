# %% [markdown]
# # AI Skincare Recommender 💆‍♀️
#
# ## 🧠 Project Overview
# Built a rule-based recommender using pandas and CSV data to suggest skincare products by skin type and concern.

# %%
df = pd.read_csv("skincare_products.csv")
df.head()
# Out:
#            Product Name    Brand     Category     Concern          Skin Type  \
# 0         Glow Cleanser  Brand A     Cleanser     Dryness        Dry, Normal
# 1            Acne Serum  Brand B        Serum        Acne  Oily, Combination
# 2     Brightening Cream  Brand C  Moisturizer  Dark spots                All
# 3         Soothing Balm  Brand D    Treatment     Redness          Sensitive
# 4  Wrinkle Repair Cream  Brand E  Moisturizer    Wrinkles                Dry
#
#    Price ($)  Rating                 Link
# 0         25     4.4  https://example.com
# 1         15     4.7  https://example.com
# 2         30     4.6  https://example.com
# 3         22     4.2  https://example.com
# 4         35     4.5  https://example.com

# %% [markdown]
# ## 🧼 Data Cleaning
# Removed missing values, normalized text casing, dropped duplicates.

# %%
import pandas as pd

# Load your skincare dataset
df = pd.read_csv("skincare_products.csv")

# Clean casing and whitespace
df['Skin Type'] = df['Skin Type'].str.strip().str.title()
df['Concern'] = df['Concern'].str.strip().str.title()

# Drop missing values and duplicates
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# Preview
df.head()
# Out:
#            Product Name    Brand     Category     Concern          Skin Type  \
# 0         Glow Cleanser  Brand A     Cleanser     Dryness        Dry, Normal
# 1            Acne Serum  Brand B        Serum        Acne  Oily, Combination
# 2     Brightening Cream  Brand C  Moisturizer  Dark Spots                All
# 3         Soothing Balm  Brand D    Treatment     Redness          Sensitive
# 4  Wrinkle Repair Cream  Brand E  Moisturizer    Wrinkles                Dry
#
#    Price ($)  Rating                 Link
# 0         25     4.4  https://example.com
# 1         15     4.7  https://example.com
# 2         30     4.6  https://example.com
# 3         22     4.2  https://example.com
# 4         35     4.5  https://example.com

# %% [markdown]
# ## 📊 Exploratory Data Analysis
# Visualized top concerns, average prices, and product ratings.

# %%
import matplotlib.pyplot as plt

df['Concern'].value_counts().plot(kind='bar', color='lightblue')
plt.title('Top Skincare Concerns')
plt.xlabel('Concern')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## 🤖 Recommendation Logic
# Filtered products by user inputs and returned top-rated matches.

# %%
# Simulated user input
user_skin_type = "Oily"
user_concern = "Acne"

# Filter matching products
results = df[
    df["Skin Type"].str.contains(user_skin_type, case=False) &
    df["Concern"].str.contains(user_concern, case=False)
]

# Top 3 recommendations
results.sort_values(by="Rating", ascending=False).head(3)
# Out:
#      Product Name    Brand Category Concern          Skin Type  Price ($)  \
# 1      Acne Serum  Brand B    Serum    Acne  Oily, Combination         15
# 5  Oil-Free Toner  Brand F    Toner    Acne               Oily         18
#
#    Rating                 Link
# 1     4.7  https://example.com
# 5     4.3  https://example.com

# %% [markdown]
# ## 📈 Insights
# Listed takeaways from the visual and numeric analysis.

# %%
df['Concern'].value_counts().plot(kind='bar', color='lightblue')
plt.title('Most Common Skincare Concerns')
plt.xlabel('Concern')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('Skin Type')['Price ($)'].mean().sort_values().plot(kind='barh', color='salmon')
plt.title('Avg. Price by Skin Type')
plt.xlabel('Avg. Price ($)')
plt.show()

# %%
df.plot.scatter(x='Price ($)', y='Rating', color='mediumorchid')
plt.title('Product Price vs. Rating')
plt.show()

# %% [markdown]
# ## 📈 Insights
# - Acne and dark spots were the most common concerns.
# - Products for dry skin were slightly more expensive on average.
# - No correlation was observed between price and rating.
